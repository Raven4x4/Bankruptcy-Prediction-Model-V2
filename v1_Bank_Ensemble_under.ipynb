# %%
# Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import joblib
import itertools

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
import lightgbm
from catboost import CatBoostClassifier

# %%
# Set seed for reproducibility
import random
import numpy as np
import tensorflow as tf

SEED = 123
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# %%
# Load dataset
df = pd.read_csv('cleaned_dataset.csv')

# Define the features and the target class
x = df.drop(columns=['target'], axis=1)
y = df['target']

#apply under sampling before splitting the data
from imblearn.under_sampling import RandomUnderSampler
rus = RandomUnderSampler(random_state=SEED)
x, y = rus.fit_resample(x, y)

# Split the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=123)

# %%
#distribution of training and testing data
print('Distribution of target class in training data')
print(y_train.value_counts())
print('Distribution of target class in testing data')
print(y_test.value_counts())
# Out:
# Distribution of target class in training data
# target
# 1    1591
# 0    1582
# Name: count, dtype: int64
# Distribution of target class in testing data
# target
# 0    685
# 1    676
# Name: count, dtype: int64

# %%
# Load the saved models 
model_paths = [
    'CatBoost.pkl',
    'DecisionTree.pkl',
    'KNN.pkl',
    'RandomForest.pkl',
    'XGBoost.pkl'
]

models = [joblib.load(path) for path in model_paths if hasattr(joblib.load(path), 'fit')]

model_names = [f'model_{i+1}' for i in range(len(models))]
estimators = list(zip(model_names, models))

# %%
# Define final estimators
final_estimators = [
    ('Logistic', LogisticRegression()),
    ('RandomForest', RandomForestClassifier()),
    ('GradientBoosting', GradientBoostingClassifier()),
    ('KNeighbors', KNeighborsClassifier()),
    ('AdaBoost', AdaBoostClassifier()),
    ('XGBoost', XGBClassifier()),
    ('GaussianNB', GaussianNB()),
    ('MLP', MLPClassifier()),
    ('LightGBM', lightgbm.LGBMClassifier(verbose=0))
]

# %%
best_score = 0
best_model = None
best_final_estimator = None
best_combination = None

total_combinations = sum([len(list(itertools.combinations(estimators, i))) for i in range(2, len(estimators) + 1)]) * len(final_estimators)
print(f'Total combinations: {total_combinations}')
count = 1

for final_estimator_name, final_estimator in final_estimators:
    for i in range(2, len(estimators) + 1):
        for combination in itertools.combinations(estimators, i):
            # Extract model names for printing
            model_names = tuple(model[0] for model in combination)
            print(f'{count} Testing combination: {model_names} with final estimator: {final_estimator_name}')
            stacking = StackingClassifier(estimators=list(combination), final_estimator=final_estimator, verbose=0)
            stacking.fit(x_train, y_train)
            y_pred = stacking.predict(x_test)
            score = accuracy_score(y_test, y_pred)
            if score > best_score:
                best_score = score
                best_model = stacking
                best_final_estimator = final_estimator_name
                best_combination = model_names
            count += 1

print(f'Best model: {best_combination} with final estimator: {best_final_estimator}')
print(f'Best score: {best_score}')
# Out:
# Total combinations: 234
# 1 Testing combination: ('model_1', 'model_2') with final estimator: Logistic
# 2 Testing combination: ('model_1', 'model_3') with final estimator: Logistic
# 3 Testing combination: ('model_1', 'model_4') with final estimator: Logistic
# 4 Testing combination: ('model_1', 'model_5') with final estimator: Logistic
# 5 Testing combination: ('model_2', 'model_3') with final estimator: Logistic
# 6 Testing combination: ('model_2', 'model_4') with final estimator: Logistic
# 7 Testing combination: ('model_2', 'model_5') with final estimator: Logistic
# 8 Testing combination: ('model_3', 'model_4') with final estimator: Logistic
# 9 Testing combination: ('model_3', 'model_5') with final estimator: Logistic
# 10 Testing combination: ('model_4', 'model_5') with final estimator: Logistic
# 11 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: Logistic
# 12 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: Logistic
# 13 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: Logistic
# 14 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: Logistic
# 15 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: Logistic
# 16 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: Logistic
# 17 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: Logistic
# 18 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: Logistic
# 19 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: Logistic
# 20 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: Logistic
# 21 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: Logistic
# 22 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: Logistic
# 23 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: Logistic
# 24 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: Logistic
# 25 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: Logistic
# 26 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: Logistic
# 27 Testing combination: ('model_1', 'model_2') with final estimator: RandomForest
# 28 Testing combination: ('model_1', 'model_3') with final estimator: RandomForest
# 29 Testing combination: ('model_1', 'model_4') with final estimator: RandomForest
# 30 Testing combination: ('model_1', 'model_5') with final estimator: RandomForest
# 31 Testing combination: ('model_2', 'model_3') with final estimator: RandomForest
# 32 Testing combination: ('model_2', 'model_4') with final estimator: RandomForest
# 33 Testing combination: ('model_2', 'model_5') with final estimator: RandomForest
# 34 Testing combination: ('model_3', 'model_4') with final estimator: RandomForest
# 35 Testing combination: ('model_3', 'model_5') with final estimator: RandomForest
# 36 Testing combination: ('model_4', 'model_5') with final estimator: RandomForest
# 37 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: RandomForest
# 38 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: RandomForest
# 39 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: RandomForest
# 40 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: RandomForest
# 41 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: RandomForest
# 42 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: RandomForest
# 43 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: RandomForest
# 44 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: RandomForest
# 45 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: RandomForest
# 46 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: RandomForest
# 47 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: RandomForest
# 48 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: RandomForest
# 49 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: RandomForest
# 50 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: RandomForest
# 51 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: RandomForest
# 52 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: RandomForest
# 53 Testing combination: ('model_1', 'model_2') with final estimator: GradientBoosting
# 54 Testing combination: ('model_1', 'model_3') with final estimator: GradientBoosting
# 55 Testing combination: ('model_1', 'model_4') with final estimator: GradientBoosting
# 56 Testing combination: ('model_1', 'model_5') with final estimator: GradientBoosting
# 57 Testing combination: ('model_2', 'model_3') with final estimator: GradientBoosting
# 58 Testing combination: ('model_2', 'model_4') with final estimator: GradientBoosting
# 59 Testing combination: ('model_2', 'model_5') with final estimator: GradientBoosting
# 60 Testing combination: ('model_3', 'model_4') with final estimator: GradientBoosting
# 61 Testing combination: ('model_3', 'model_5') with final estimator: GradientBoosting
# 62 Testing combination: ('model_4', 'model_5') with final estimator: GradientBoosting
# 63 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: GradientBoosting
# 64 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: GradientBoosting
# 65 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: GradientBoosting
# 66 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: GradientBoosting
# 67 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: GradientBoosting
# 68 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: GradientBoosting
# 69 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: GradientBoosting
# 70 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: GradientBoosting
# 71 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: GradientBoosting
# 72 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: GradientBoosting
# 73 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: GradientBoosting
# 74 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: GradientBoosting
# 75 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: GradientBoosting
# 76 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: GradientBoosting
# 77 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: GradientBoosting
# 78 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: GradientBoosting
# 79 Testing combination: ('model_1', 'model_2') with final estimator: KNeighbors
# 80 Testing combination: ('model_1', 'model_3') with final estimator: KNeighbors
# 81 Testing combination: ('model_1', 'model_4') with final estimator: KNeighbors
# 82 Testing combination: ('model_1', 'model_5') with final estimator: KNeighbors
# 83 Testing combination: ('model_2', 'model_3') with final estimator: KNeighbors
# 84 Testing combination: ('model_2', 'model_4') with final estimator: KNeighbors
# 85 Testing combination: ('model_2', 'model_5') with final estimator: KNeighbors
# 86 Testing combination: ('model_3', 'model_4') with final estimator: KNeighbors
# 87 Testing combination: ('model_3', 'model_5') with final estimator: KNeighbors
# 88 Testing combination: ('model_4', 'model_5') with final estimator: KNeighbors
# 89 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: KNeighbors
# 90 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: KNeighbors
# 91 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: KNeighbors
# 92 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: KNeighbors
# 93 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: KNeighbors
# 94 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: KNeighbors
# 95 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: KNeighbors
# 96 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: KNeighbors
# 97 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: KNeighbors
# 98 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: KNeighbors
# 99 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: KNeighbors
# 100 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: KNeighbors
# 101 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: KNeighbors
# 102 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: KNeighbors
# 103 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: KNeighbors
# 104 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: KNeighbors
# 105 Testing combination: ('model_1', 'model_2') with final estimator: AdaBoost
# 106 Testing combination: ('model_1', 'model_3') with final estimator: AdaBoost
# 107 Testing combination: ('model_1', 'model_4') with final estimator: AdaBoost
# 108 Testing combination: ('model_1', 'model_5') with final estimator: AdaBoost
# 109 Testing combination: ('model_2', 'model_3') with final estimator: AdaBoost
# 110 Testing combination: ('model_2', 'model_4') with final estimator: AdaBoost
# 111 Testing combination: ('model_2', 'model_5') with final estimator: AdaBoost
# 112 Testing combination: ('model_3', 'model_4') with final estimator: AdaBoost
# 113 Testing combination: ('model_3', 'model_5') with final estimator: AdaBoost
# 114 Testing combination: ('model_4', 'model_5') with final estimator: AdaBoost
# 115 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: AdaBoost
# 116 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: AdaBoost
# 117 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: AdaBoost
# 118 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: AdaBoost
# 119 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: AdaBoost
# 120 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: AdaBoost
# 121 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: AdaBoost
# 122 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: AdaBoost
# 123 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: AdaBoost
# 124 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: AdaBoost
# 125 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: AdaBoost
# 126 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: AdaBoost
# 127 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: AdaBoost
# 128 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: AdaBoost
# 129 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: AdaBoost
# 130 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: AdaBoost
# 131 Testing combination: ('model_1', 'model_2') with final estimator: XGBoost
# 132 Testing combination: ('model_1', 'model_3') with final estimator: XGBoost
# 133 Testing combination: ('model_1', 'model_4') with final estimator: XGBoost
# 134 Testing combination: ('model_1', 'model_5') with final estimator: XGBoost
# 135 Testing combination: ('model_2', 'model_3') with final estimator: XGBoost
# 136 Testing combination: ('model_2', 'model_4') with final estimator: XGBoost
# 137 Testing combination: ('model_2', 'model_5') with final estimator: XGBoost
# 138 Testing combination: ('model_3', 'model_4') with final estimator: XGBoost
# 139 Testing combination: ('model_3', 'model_5') with final estimator: XGBoost
# 140 Testing combination: ('model_4', 'model_5') with final estimator: XGBoost
# 141 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: XGBoost
# 142 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: XGBoost
# 143 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: XGBoost
# 144 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: XGBoost
# 145 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: XGBoost
# 146 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: XGBoost
# 147 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: XGBoost
# 148 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: XGBoost
# 149 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: XGBoost
# 150 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: XGBoost
# 151 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: XGBoost
# 152 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: XGBoost
# 153 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: XGBoost
# 154 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: XGBoost
# 155 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: XGBoost
# 156 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: XGBoost
# 157 Testing combination: ('model_1', 'model_2') with final estimator: GaussianNB
# 158 Testing combination: ('model_1', 'model_3') with final estimator: GaussianNB
# 159 Testing combination: ('model_1', 'model_4') with final estimator: GaussianNB
# 160 Testing combination: ('model_1', 'model_5') with final estimator: GaussianNB
# 161 Testing combination: ('model_2', 'model_3') with final estimator: GaussianNB
# 162 Testing combination: ('model_2', 'model_4') with final estimator: GaussianNB
# 163 Testing combination: ('model_2', 'model_5') with final estimator: GaussianNB
# 164 Testing combination: ('model_3', 'model_4') with final estimator: GaussianNB
# 165 Testing combination: ('model_3', 'model_5') with final estimator: GaussianNB
# 166 Testing combination: ('model_4', 'model_5') with final estimator: GaussianNB
# 167 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: GaussianNB
# 168 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: GaussianNB
# 169 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: GaussianNB
# 170 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: GaussianNB
# 171 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: GaussianNB
# 172 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: GaussianNB
# 173 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: GaussianNB
# 174 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: GaussianNB
# 175 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: GaussianNB
# 176 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: GaussianNB
# 177 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: GaussianNB
# 178 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: GaussianNB
# 179 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: GaussianNB
# 180 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: GaussianNB
# 181 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: GaussianNB
# 182 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: GaussianNB
# 183 Testing combination: ('model_1', 'model_2') with final estimator: MLP
# 184 Testing combination: ('model_1', 'model_3') with final estimator: MLP
# 185 Testing combination: ('model_1', 'model_4') with final estimator: MLP
# 186 Testing combination: ('model_1', 'model_5') with final estimator: MLP
# 187 Testing combination: ('model_2', 'model_3') with final estimator: MLP
# 188 Testing combination: ('model_2', 'model_4') with final estimator: MLP
# 189 Testing combination: ('model_2', 'model_5') with final estimator: MLP
# 190 Testing combination: ('model_3', 'model_4') with final estimator: MLP
# 191 Testing combination: ('model_3', 'model_5') with final estimator: MLP
# 192 Testing combination: ('model_4', 'model_5') with final estimator: MLP
# 193 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: MLP
# 194 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: MLP
# 195 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: MLP
# 196 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: MLP
# 197 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: MLP
# 198 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: MLP
# 199 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: MLP
# 200 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: MLP
# 201 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: MLP
# 202 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: MLP
# 203 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: MLP
# 204 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: MLP
# 205 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: MLP
# 206 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: MLP
# 207 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: MLP
# 208 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: MLP
# 209 Testing combination: ('model_1', 'model_2') with final estimator: LightGBM
# 210 Testing combination: ('model_1', 'model_3') with final estimator: LightGBM
# 211 Testing combination: ('model_1', 'model_4') with final estimator: LightGBM
# 212 Testing combination: ('model_1', 'model_5') with final estimator: LightGBM
# 213 Testing combination: ('model_2', 'model_3') with final estimator: LightGBM
# 214 Testing combination: ('model_2', 'model_4') with final estimator: LightGBM
# 215 Testing combination: ('model_2', 'model_5') with final estimator: LightGBM
# 216 Testing combination: ('model_3', 'model_4') with final estimator: LightGBM
# 217 Testing combination: ('model_3', 'model_5') with final estimator: LightGBM
# 218 Testing combination: ('model_4', 'model_5') with final estimator: LightGBM
# 219 Testing combination: ('model_1', 'model_2', 'model_3') with final estimator: LightGBM
# 220 Testing combination: ('model_1', 'model_2', 'model_4') with final estimator: LightGBM
# 221 Testing combination: ('model_1', 'model_2', 'model_5') with final estimator: LightGBM
# 222 Testing combination: ('model_1', 'model_3', 'model_4') with final estimator: LightGBM
# 223 Testing combination: ('model_1', 'model_3', 'model_5') with final estimator: LightGBM
# 224 Testing combination: ('model_1', 'model_4', 'model_5') with final estimator: LightGBM
# 225 Testing combination: ('model_2', 'model_3', 'model_4') with final estimator: LightGBM
# 226 Testing combination: ('model_2', 'model_3', 'model_5') with final estimator: LightGBM
# 227 Testing combination: ('model_2', 'model_4', 'model_5') with final estimator: LightGBM
# 228 Testing combination: ('model_3', 'model_4', 'model_5') with final estimator: LightGBM
# 229 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4') with final estimator: LightGBM
# 230 Testing combination: ('model_1', 'model_2', 'model_3', 'model_5') with final estimator: LightGBM
# 231 Testing combination: ('model_1', 'model_2', 'model_4', 'model_5') with final estimator: LightGBM
# 232 Testing combination: ('model_1', 'model_3', 'model_4', 'model_5') with final estimator: LightGBM
# 233 Testing combination: ('model_2', 'model_3', 'model_4', 'model_5') with final estimator: LightGBM
# 234 Testing combination: ('model_1', 'model_2', 'model_3', 'model_4', 'model_5') with final estimator: LightGBM
# Best model: ('model_1', 'model_2', 'model_5') with final estimator: GradientBoosting
# Best score: 0.7421013960323292

# %%
# Evaluate the stacking ensemble
y_pred_train = best_model.predict(x_train)
y_pred_test = best_model.predict(x_test)

train_accuracy = accuracy_score(y_train, y_pred_train) * 100
test_accuracy = accuracy_score(y_test, y_pred_test) * 100

print(f"Test Accuracy: {test_accuracy:.2f}%\n")

print('Accuracy: ', accuracy_score(y_test, y_pred_test) * 100)
print('Recall: ', recall_score(y_test, y_pred_test, average='weighted') * 100)
print('Precision: ', precision_score(y_test, y_pred_test, average='weighted') * 100)
print('F1-Score: ', f1_score(y_test, y_pred_test, average='weighted') * 100)

# Compute ROC curve and AUC score
y_pred_prob = best_model.predict_proba(x_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1],'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.title('ROC curve for classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()

print("AUC Score:", roc_auc_score(y_test, y_pred_prob))
# Out:
# Test Accuracy: 74.21%
#
# Accuracy:  74.21013960323292
# Recall:  74.21013960323292
# Precision:  74.54318921254796
# F1-Score:  74.1370563493025
# AUC Score: 0.8018410141234398

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_test)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=best_model.classes_)
cm_display.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
# Save the stacking model
stacking_model_file = "Ensemble models\V1_Ensemble_stacking_model_under.pkl"
joblib.dump(best_model, stacking_model_file)
# Out:
# ['Ensemble models\\V1_Ensemble_stacking_model_under.pkl']

# %%
import joblib
# Load and test the saved model
loaded_stacking_model = joblib.load("Ensemble models\V1_Ensemble_stacking_model_under.pkl")
print('Loaded stacking model accuracy:', accuracy_score(y_test, loaded_stacking_model.predict(x_test)) * 100)
# Out:
# Loaded stacking model accuracy: 74.21013960323292

# %%
#load the model and check the accuracy, recall, precision, f1-score, and plot the confusion matrix and ROC curve
stacking_model_file = "Ensemble models\V1_Ensemble_stacking_model_under.pkl"
loaded_stacking_model = joblib.load(stacking_model_file)
y_pred_test = loaded_stacking_model.predict(x_test)
print('Accuracy: ', accuracy_score(y_test, y_pred_test) * 100)
print('Precision: ', precision_score(y_test, y_pred_test) * 100)
print('Recall: ', recall_score(y_test, y_pred_test) * 100)
print('F1-Score: ', f1_score(y_test, y_pred_test) * 100)

# Compute ROC curve and AUC score
y_pred_prob = loaded_stacking_model.predict_proba(x_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot(fpr, tpr)
plt.plot([0,1],[0,1],'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.title('ROC curve for classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
plt.show()

print("AUC Score:", roc_auc_score(y_test, y_pred_prob))

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_test)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
cm_display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=loaded_stacking_model.classes_)
cm_display.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy:  74.21013960323292
# Precision:  71.58034528552457
# Recall:  79.73372781065089
# F1-Score:  75.43736878936319
# AUC Score: 0.8018410141234398

# %%
import winsound
# Play a sound to indicate the end of the process
winsound.MessageBeep()
